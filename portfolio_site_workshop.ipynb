# %% [markdown]
# # Portfolio Site Workshop
#
# While waiting:
#
# 1. Open this page: [**afeld.me/psw**](https://afeld.me/psw)
# 1. [Install Python 3.13+.](https://www.python.org/downloads/) _\[once per computer\]_
#    - Not the `pre-release`
# 1. [Install VSCode.](https://code.visualstudio.com/download) _\[once per computer\]_
# 1. [Sign up for GitHub.](https://github.com/) _\[once\]_
# 1. [Open the terminal.](https://code.visualstudio.com/docs/terminal/getting-started)
# 1. [Install Git.](week_8.md#install-git) _\[once per computer\]_
#
# _Skip any steps that you've already done._

# %% [markdown]
# ## About me
#
# - Coding since 2005 🖥
# - Government since 2014 🦅
# - Teaching since 2011 🎓
# - Also a modern dancer 💃 and cyclist 🚲

# %% [markdown]
# ### SIPA
#
# Adjunct who teaches:
#
# - [Python for Public Policy](https://python-public-policy.afeld.me/en/columbia/)
# - [Computing in Context](index.md)
# - [Advanced Computing for Policy](https://github.com/advanced-computing/course-materials/blob/main/README.md)
#
# [Relationship between them.](https://docs.google.com/drawings/d/1PjJG2TdWk-JMU_G2X3BV6ue0N9y5tZUN7FNJ3C8yPX8/edit)

# %% [markdown]
# - You'll be given a bunch of instructions without (fully) understanding what they do. That's ok.
# - The instructions are very specific, follow them closely.

# %% [markdown]
# ## Git
#
# ### Git setup
#
# 1. Create `[username].github.io` folder, wherever.
#    - For example, mine is `afeld.github.io`
# 1. [Open the folder in VSCode.](https://code.visualstudio.com/docs/getstarted/getting-started#_open-a-folder-in-vs-code)
# 1. Set global [name](https://docs.github.com/en/get-started/getting-started-with-git/setting-your-username-in-git) and [email](https://docs.github.com/en/account-and-profile/setting-up-and-managing-your-personal-account-on-github/managing-email-preferences/setting-your-commit-email-address#setting-your-commit-email-address-in-git) in Git.
#    - Your name and email can be set to whatever.

# %% [markdown]
# ### Local repository setup
#
# [_\[once per working folder\]_](https://computing-in-context.afeld.me/lecture_16.html#where-we-re-going)
#
# 1. In sidebar, click [Source Control](https://code.visualstudio.com/docs/sourcecontrol/overview).
# 1. [`Initialize Repository`](https://code.visualstudio.com/docs/sourcecontrol/overview#_initialize-a-repository)
# 1. You should see a bunch of files under `Changes`.

# %% [markdown]
# ### [gitignore](https://docs.github.com/en/get-started/git-basics/ignoring-files#configuring-ignored-files-for-a-single-repository)
#
# 1. Create a `.gitignore` file containing the following: _\[once per repository\]_
#
#    ```
#    .DS_Store
#    .ipynb_checkpoints/
#    _build/
#    ```
#
# 1. You should now see only the following under `Changes`:
#    - `.gitignore`
#    - `lecture_16_example.ipynb`
#    - `requirements.txt`

# %% [markdown]
# ### [Commit](https://code.visualstudio.com/docs/sourcecontrol/overview#_commit)
#
# - Use a meaningful commit message, like "adding example notebook and gitignore".
# - If it asks about "There are no staged changes", click "Always".

# %% [markdown]
# ### Make changes
#
# 1. In `lecture_16_example.ipynb`, add a [Markdown cell](https://computing-in-context.afeld.me/lecture_16.html#jupyter-basics) at the top with a [heading (level 1)](https://www.markdownguide.org/basic-syntax/#headings).
#
#    ```md
#    # Lecture 16 Example
#    ```
#
# 1. Commit.
# 1. Your [Source Control Graph](https://code.visualstudio.com/docs/sourcecontrol/overview#_source-control-graph) (a.k.a. your Git history) should then look something like this:
#
#    ![Git history](img/git_history.png)

# %% [markdown]
# ## GitHub
#
# If you miss a step, don't worry - it's possible to do them out of order. Ask for help if you need.
#
# 1. Click [`Publish Branch`](https://code.visualstudio.com/docs/sourcecontrol/intro-to-git#_using-branches).
# 1. [Allow signing in with GitHub](https://code.visualstudio.com/docs/sourcecontrol/github#_authenticating-with-an-existing-repository), if prompted. _\[once per computer\]_
# 1. Click `Publish to GitHub public repository`. [_\[once per repository\]_](https://computing-in-context.afeld.me/lecture_16.html#where-we-re-going)
#    - [Public vs. private](https://docs.github.com/en/repositories/creating-and-managing-repositories/about-repositories#about-repository-visibility)
# 1. [Have VSCode periodically fetch](https://code.visualstudio.com/docs/sourcecontrol/overview#_remotes), if asked.
# 1. Visit the repository on GitHub.
#    1. Click into the files.

# %% [markdown]
# ### Make changes
#
# 1. In VSCode, add an `index.md` file with the following. (You can expand it later.)
#
#    ```md
#    # [Your name]'s Portfolio
#
#    Welcome! Work in progress.
#    ```
#
# 1. Commit.
# 1. [Push (a.k.a. "sync")](https://code.visualstudio.com/docs/sourcecontrol/overview#_remotes) the change to GitHub.

# %% [markdown]
# ### View
#
# Open the repository on GitHub, which should look something like this:
#
# ![repository file list](img/repo_initial.png)

# %% [markdown]
# ## [Jupyter Book](https://jupyterbook.org/)
#
# - [Static website builder](https://jupyterbook.org/v1/publish/web.html)
# - Used to build the [course site](https://computing-in-context.afeld.me/)

# %% [markdown]
# ### Install
#
# Add this to your `requirements.txt`:
#
# ```
# jupyter-book==2.*
# ```
#
# then [install the packages](https://computing-in-context.afeld.me/notebooks.html#installing-packages).
#
# _The install might take a while; you can continue up until [building the site](#build-the-site) in the meantime._

# %% [markdown]
# ### [Initialize the site](https://jupyterbook.org/stable/get-started/init/)
#
# [Open the integrated terminal](https://code.visualstudio.com/docs/terminal/getting-started) and run:
#
# ```sh
# jupyter book init --write-toc
# ```

# %% [markdown]
# #### [Troubleshooting](https://computing-in-context.afeld.me/notebooks.html#jupyter-book)

# %% [markdown]
# ### [View the site (locally)](https://jupyterbook.org/stable/get-started/build-websites/)

# %% [markdown]
# ### Push to GitHub
#
# 1. [View the diff](https://code.visualstudio.com/docs/sourcecontrol/overview#_viewing-diffs)
# 1. Commit
# 1. Push
# 1. The GitHub repository should then look like this:
#
#    ![repository with Jupyter Book files](img/repo_book.png)

# %% [markdown]
# ## Deploy the site
#
# To make your site visible to others, [deploy to GitHub pages](https://jupyterbook.org/stable/get-started/publish/#github-pages). <!-- Using `latest` to show https://github.com/jupyter-book/jupyter-book/pull/2421. -->

# %% [markdown]
# Check the site: `https://[username].github.io`

# %% [markdown]
# You are more than welcome to customize the site as much as you like, but make sure you finish the assigned work first.

# %% [markdown]
# ## Learning more
#
# Take [Computing in Context](index.md)!
