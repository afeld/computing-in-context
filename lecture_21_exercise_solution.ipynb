# %% [markdown]
# # [Lecture 21 In-Class Exercise](https://computing-in-context.afeld.me/lecture_21.html#in-class-exercise) Solution

# %% [markdown]
# [Fix rendering:](https://computing-in-context.afeld.me/notebooks.html#jupyter-book)

# %%
import plotly.io as pio

pio.renderers.default = "notebook_connected+plotly_mimetype"

# %% [markdown]
# ## Download data
#
# [More about the URL below.](https://datahelpdesk.worldbank.org/knowledgebase/articles/898581-api-basic-call-structures) This code does the download and unzipping; not expecting your code to do that.

# %%
import urllib.request
from pathlib import Path

data_dir = Path("data")
# Create data/ directory if it doesn't exist
data_dir.mkdir(exist_ok=True)

# Download the file
url = "https://api.worldbank.org/v2/country/all/indicator/EG.ELC.ACCS.ZS?source=2&date=2002:2022&downloadformat=csv"
zip_path = data_dir / "electricity.zip"
urllib.request.urlretrieve(url, zip_path)
print(f"Downloaded {zip_path}.")
# Out:
# Downloaded data/electricity.zip.

# %%
from zipfile import ZipFile

# Extract the zip file
electricity_dir = data_dir / "electricity"
with ZipFile(zip_path, "r") as zip_ref:
    zip_ref.extractall(electricity_dir)

print(f"Extracted to {electricity_dir}.")
# Out:
# Extracted to data/electricity.

# %% [markdown]
# ## Load data

# %%
import pandas as pd

electricity_file = electricity_dir / "API_EG.ELC.ACCS.ZS_DS2_EN_csv_v2_225978.csv"
electricity = pd.read_csv(electricity_file, header=2)
electricity
# Out:
# <frozen importlib._bootstrap>:491: RuntimeWarning:
#
# The global interpreter lock (GIL) has been enabled to load module 'pandas._libs.pandas_parser', which has not declared that it can run safely without the GIL. To override this behavior and keep the GIL disabled (at your own risk), run with PYTHON_GIL=0 or -Xgil=0.
#                     Country Name Country Code  \
# 0                          Aruba          ABW
# 1    Africa Eastern and Southern          AFE
# 2                    Afghanistan          AFG
# 3     Africa Western and Central          AFW
# 4                         Angola          AGO
# ..                           ...          ...
# 261                       Kosovo          XKX
# 262                  Yemen, Rep.          YEM
# 263                 South Africa          ZAF
# 264                       Zambia          ZMB
# 265                     Zimbabwe          ZWE
#
#                               Indicator Name  Indicator Code        2002  \
# 0    Access to electricity (% of population)  EG.ELC.ACCS.ZS  100.000000
# 1    Access to electricity (% of population)  EG.ELC.ACCS.ZS   21.548647
# 2    Access to electricity (% of population)  EG.ELC.ACCS.ZS   14.100000
# 3    Access to electricity (% of population)  EG.ELC.ACCS.ZS   35.809111
# 4    Access to electricity (% of population)  EG.ELC.ACCS.ZS   26.300000
# ..                                       ...             ...         ...
# 261  Access to electricity (% of population)  EG.ELC.ACCS.ZS         NaN
# 262  Access to electricity (% of population)  EG.ELC.ACCS.ZS   51.500000
# 263  Access to electricity (% of population)  EG.ELC.ACCS.ZS   76.700000
# 264  Access to electricity (% of population)  EG.ELC.ACCS.ZS   17.400000
# 265  Access to electricity (% of population)  EG.ELC.ACCS.ZS   34.200000
#
#            2003        2004        2005        2006        2007  ...  \
# 0    100.000000  100.000000  100.000000  100.000000  100.000000  ...
# 1     22.493217   23.724455   23.449539   25.172482   26.795145  ...
# 2     19.000000   23.800000   28.700000   33.500000   38.400000  ...
# 3     39.960254   37.594502   37.935910   39.952904   40.864862  ...
# 4     27.400000   28.400000   29.400000   30.500000   37.500000  ...
# ..          ...         ...         ...         ...         ...  ...
# 261         NaN         NaN         NaN         NaN         NaN  ...
# 262   52.600000   49.600000   54.800000   55.800000   57.200000  ...
# 263   78.800000   80.600000   80.800000   80.700000   82.000000  ...
# 264   18.500000   20.300000   23.300000   24.100000   18.500000  ...
# 265   35.100000   35.600000   36.100000   37.200000   37.200000  ...
#
#            2014        2015        2016        2017        2018        2019  \
# 0    100.000000  100.000000  100.000000  100.000000  100.000000  100.000000
# 1     31.871956   33.922276   38.859598   40.223744   43.035073   44.390861
# 2     89.500000   71.500000   97.700000   97.700000   93.400000   97.700000
# 3     47.767361   46.862418   51.045127   48.900728   51.335829   51.291577
# 4     32.000000   42.000000   41.800000   42.900000   45.300000   45.600000
# ..          ...         ...         ...         ...         ...         ...
# 261         NaN         NaN         NaN         NaN         NaN         NaN
# 262   66.100000   67.400000   68.900000   79.200000   62.000000   72.800000
# 263   85.900000   85.300000   83.900000   84.400000   84.700000   85.000000
# 264   27.900000   31.100000   35.400000   40.300000   40.200000   43.000000
# 265   32.300000   33.700000   42.500000   44.000000   45.400000   46.700000
#
#            2020        2021       2022  Unnamed: 25
# 0    100.000000  100.000000  99.900000          NaN
# 1     46.282371   48.127211  48.801258          NaN
# 2     97.700000   97.700000  85.300000          NaN
# 3     51.856043   54.368599  55.686683          NaN
# 4     47.000000   48.200000  48.500000          NaN
# ..          ...         ...        ...          ...
# 261         NaN         NaN        NaN          NaN
# 262   73.900000   74.900000  76.000000          NaN
# 263   90.000000   89.300000  86.500000          NaN
# 264   44.600000   46.700000  47.800000          NaN
# 265   52.700000   49.000000  50.100000          NaN
#
# [266 rows x 26 columns]

# %% [markdown]
# ## [Reshape](https://pandas.pydata.org/docs/user_guide/reshaping.html#melt-and-wide-to-long)

# %%
electricity_by_country_by_year = (
    electricity.drop(columns=["Indicator Name", "Indicator Code"])
    .melt(
        id_vars=["Country Name", "Country Code"],
        var_name="Year",
        value_name="Access to electricity (% of population)",
    )
    .dropna()
)

electricity_by_country_by_year
# Out:
#                      Country Name Country Code  Year  \
# 0                           Aruba          ABW  2002
# 1     Africa Eastern and Southern          AFE  2002
# 2                     Afghanistan          AFG  2002
# 3      Africa Western and Central          AFW  2002
# 4                          Angola          AGO  2002
# ...                           ...          ...   ...
# 5580                        Samoa          WSM  2022
# 5582                  Yemen, Rep.          YEM  2022
# 5583                 South Africa          ZAF  2022
# 5584                       Zambia          ZMB  2022
# 5585                     Zimbabwe          ZWE  2022
#
#       Access to electricity (% of population)
# 0                                  100.000000
# 1                                   21.548647
# 2                                   14.100000
# 3                                   35.809111
# 4                                   26.300000
# ...                                       ...
# 5580                                98.300000
# 5582                                76.000000
# 5583                                86.500000
# 5584                                47.800000
# 5585                                50.100000
#
# [5506 rows x 4 columns]

# %% [markdown]
# ## Plot

# %%
import plotly.express as px

fig = px.line(
    electricity_by_country_by_year,
    x="Year",
    y="Access to electricity (% of population)",
    color="Country Name",
    title="Access to electricity over time",
)
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.3.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="6c179d63-ad2f-4407-a8be-a88dc35e73c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6c179d63-ad2f-4407-a8be-a88dc35e73c8")) {                    Plotly.newPlot(                        "6c179d63-ad2f-4407-a8be-a88dc35e73c8",                        [{"hovertemplate":"Country Name=Aruba\u003cbr\u003eYear=%{x}\u003cbr\u003eAccess to electricity (% of population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Aruba","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Aruba","showlegend":true,"x":["2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"xaxis":"x","y":{"dtype":"f8","bdata":"AAAAAAAAWUAAAAAAAABZQAAAAAAAAFlAAAAAAAAAWUAAAAAAAABZQAAAAAAAAFlAAAAAAAAAWUAAAAAAAABZQJqZmZmZWVdAAAAAAAAAWUAAAAAAAABZQAAAAAAAAFlAAAAAAAAAWUAAAAAAAABZQAAAAAAAAFlAAAAAAAAAWUAAAAAAAABZQAAAAAAAAFlAAAAAAAAAWUAAAAAAAABZQJqZmZmZ+VhA"},"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country Name=Africa Eastern and Southern\u003cbr\u003eYear=%{x}\u003cbr\u003eAccess to electricity (% of population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Africa Eastern and Southern","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Africa Eastern and Southern","showlegend":true,"x":["2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"xaxis":"x","y":{"dtype":"f8","bdata":"6+bGGnSMNUAjiGpzQ342QN8B4+B1uTdAupfeAhVzN0D3JvvMJyw5QDNieZiOyzpAsJIhE6roOUDtJ\u002fC0FjA6QF3MzGg6ajtAV+jYyOXoPED4Kf29Zaw\u002fQPzrIB48uT9ADthOhDjfP0CHr\u002f8gDfZAQDA2y0sHbkNAi+4opqMcREDDSZdIfYRFQCsMzLcHMkZAskQsuyQkR0BnWYxzSBBIQAuT8J6PZkhA"},"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country Name=Afghanistan\u003cbr\u003eYear=%{x}\u003cbr\u003eAccess to electricity (% of population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","showlegend":true,"x":["2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"xaxis":"x","y":{"dtype":"f8","bdata":"MzMzMzMzLEAAAAAAAAAzQM3MzMzMzDdAMzMzMzOzPEAAAAAAAMBAQDMzMzMzM0NAMzMzMzMzRUBmZmZmZiZIQJqZmZmZWUVAmpmZmZmZRUBmZmZmZkZRQAAAAAAAAFFAAAAAAABgVkAAAAAAAOBRQM3MzMzMbFhAzczMzMxsWECamZmZmVlXQM3MzMzMbFhAzczMzMxsWEDNzMzMzGxYQDMzMzMzU1VA"},"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country Name=Africa Western and Central\u003cbr\u003eYear=%{x}\u003cbr\u003eAccess to electricity (% of population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Africa Western and Central","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Africa Western and Central","showlegend":true,"x":["2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021","2022"],"xaxis":"x","y":{"dtype":"f8","bdata":"X4e18pDnQUA7dNWZ6fpDQKr\u002fQaYYzEJAr+VC58v3QkDY2SnG+PlDQCM5WsuzbkRA4TqEkdnuREB6+mFxUQBFQBbbi9Ha+URAsWE3iO4HR0CAmE4+3xdGQO1\u002fCXrlmEdAAirR3jjiR0B88qa4Y25HQNsvVLrGhUlAP1CBDktzSECraMl0\u002fKpJQPynaWRSpUlAZW7ez5LtSUCyDhM+Li9LQObyOjrl10tA"},"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country Name=Angola\u003cbr\u003eYear=%{x}\u003cbr\u003eAccess to electricity (% of population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Angola","line":{" ...

# %% [markdown]
# Plotly showing that many values on an axis (the `Year` in this case) indicates that it's a string.

# %% [markdown]
# ## Fix year dtype

# %%
electricity_by_country_by_year.dtypes
# Out:
# Country Name                                object
# Country Code                                object
# Year                                        object
# Access to electricity (% of population)    float64
# dtype: object

# %%
electricity_by_country_by_year["Year"] = electricity_by_country_by_year["Year"].astype(int)

# %% [markdown]
# ## Filter

# %%
avg_electricity = electricity_by_country_by_year.groupby("Country Name")["Access to electricity (% of population)"].mean()
avg_electricity
# Out:
# Country Name
# Afghanistan                    61.876190
# Africa Eastern and Southern    32.881725
# Africa Western and Central     45.452160
# Albania                        99.757143
# Algeria                        99.142857
#                                  ...
# West Bank and Gaza             99.742857
# World                          85.250561
# Yemen, Rep.                    63.404762
# Zambia                         30.523810
# Zimbabwe                       40.633333
# Name: Access to electricity (% of population), Length: 263, dtype: float64

# %%
bottom_cutoff = avg_electricity.quantile(0.05)
bottom_cutoff
# Out:
# np.float64(21.837142857142858)

# %%
bottom_countries = avg_electricity[avg_electricity < bottom_cutoff]
bottom_countries
# Out:
# Country Name
# Burkina Faso                14.676190
# Burundi                      6.547619
# Central African Republic    10.990476
# Chad                         7.566667
# Congo, Dem. Rep.            14.438095
# Guinea-Bissau               16.771429
# Liberia                     14.768750
# Madagascar                  21.823810
# Malawi                       9.547619
# Mozambique                  20.528571
# Niger                       14.133333
# Papua New Guinea            16.957143
# Sierra Leone                17.604762
# South Sudan                  4.475000
# Name: Access to electricity (% of population), dtype: float64

# %%
bottom_countries_electricity = electricity_by_country_by_year[electricity_by_country_by_year["Country Name"].isin(bottom_countries.index)]

fig = px.line(
    bottom_countries_electricity,
    x="Year",
    y="Access to electricity (% of population)",
    color="Country Name",
    title="Access to electricity over time by country, 5th percentile",
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="5756a993-b2ee-4001-a052-db9e610fbe11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("5756a993-b2ee-4001-a052-db9e610fbe11")) {                    Plotly.newPlot(                        "5756a993-b2ee-4001-a052-db9e610fbe11",                        [{"hovertemplate":"Country Name=Burundi\u003cbr\u003eYear=%{x}\u003cbr\u003eAccess to electricity (% of population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Burundi","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Burundi","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH5AflB+YH"},"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMCEAzMzMzMzMLQJqZmZmZmQ1AmpmZmZmZCUCamZmZmZkFQM3MzMzMzBJAMzMzMzMzE0CamZmZmZkVQDMzMzMzMxVAzczMzMzMGEAAAAAAAAAaQJqZmZmZmRtAAAAAAAAAHECamZmZmZkfQAAAAAAAACFAmpmZmZmZIkAAAAAAAAAjQJqZmZmZmSNAMzMzMzMzIkBmZmZmZmYkQJqZmZmZmSRA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Burkina Faso\u003cbr\u003eYear=%{x}\u003cbr\u003eAccess to electricity (% of population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Burkina Faso","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Burkina Faso","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH5AflB+YH"},"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMI0DNzMzMzMwmQGZmZmZmZiVAMzMzMzMzJkAzMzMzMzMnQAAAAAAAAChAAAAAAAAAKUAzMzMzMzMpQDMzMzMzMypAmpmZmZmZLUAzMzMzMzMuQM3MzMzMzC5AMzMzMzMzM0AzMzMzMzMwQJqZmZmZmTBAAAAAAAAAMUDNzMzMzMwsQJqZmZmZmTFAAAAAAACAMkAAAAAAAAAzQAAAAAAAgDNA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Central African Republic\u003cbr\u003eYear=%{x}\u003cbr\u003eAccess to electricity (% of population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Central African Republic","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Central African Republic","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH5AflB+YH"},"xaxis":"x","y":{"dtype":"f8","bdata":"ZmZmZmZmGEBmZmZmZmYaQAAAAAAAABxAmpmZmZmZHUAzMzMzMzMfQM3MzMzMzCBAAAAAAAAAHkDNzMzMzMwiQJqZmZmZmSNAzczMzMzMJEAAAAAAAAAmQAAAAAAAACdAAAAAAAAAKEBmZmZmZmYpQM3MzMzMzCpAMzMzMzMzLEAzMzMzMzMtQJqZmZmZmSxAzczMzMzMLkBmZmZmZmYvQGZmZmZmZi9A"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Congo, Dem. Rep.\u003cbr\u003eYear=%{x}\u003cbr\u003eAccess to electricity (% of population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Congo, Dem. Rep.","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Congo, Dem. Rep.","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH5AflB+YH"},"xaxis":"x","y":{"dtype":"f8","bdata":"zczMzMzMHkCamZmZmZkgQAAAAAAAACJAAAAAAAAAGEBmZmZmZmYkQGZmZmZmZi5AMzMzMzMzJ0CamZmZmZkoQAAAAAAAACpAZmZmZmZmK0DNzMzMzMwuQGZmZmZmZi5AAAAAAAAAK0CamZmZmZkwQM3MzMzMTDFAAAAAAAAAMkAzMzMzM7MyQJqZmZmZGTNAmpmZmZkZNEDNzMzMzMw0QAAAAAAAgDVA"},"yaxis":"y","type":"scatter"},{"hovertemplate":"Country Name=Guinea-Bissau\u003cbr\u003eYear=%{x}\u003cbr\u003eAccess to electricity (% of population)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Guinea-Bissau","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Guinea-Bissau","orientation":"v","showlegend":true,"x":{"dtype":"i2","bdata":"0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH5AflB+YH"},"xaxis":"x","y":{"dtype":"f8 ...

# %% [markdown]
# ## [World Happiness Report data](https://www.worldhappiness.report/data-sharing/)
#
# [Requires `openpyxl` package.](https://pandas.pydata.org/docs/user_guide/io.html#excel-files) [How to install.](https://computing-in-context.afeld.me/notebooks.html#installing-packages)

# %%
happiness = pd.read_excel("https://files.worldhappiness.report/WHR25_Data_Figure_2.1v3.xlsx")
happiness
# Out:
#       Year  Rank Country name  Life evaluation (3-year average)  \
# 0     2024   147  Afghanistan                             1.364
# 1     2023   143  Afghanistan                             1.721
# 2     2022   137  Afghanistan                             1.859
# 3     2021   146  Afghanistan                             2.404
# 4     2020   150  Afghanistan                             2.523
# ...    ...   ...          ...                               ...
# 1964  2016   138     Zimbabwe                             3.875
# 1965  2015   131     Zimbabwe                             4.193
# 1966  2014   115     Zimbabwe                             4.610
# 1967  2012   103     Zimbabwe                             4.827
# 1968  2011   142     Zimbabwe                             3.978
#
#       Lower whisker  Upper whisker  Explained by: Log GDP per capita  \
# 0             1.301          1.427                             0.649
# 1             1.667          1.775                             0.628
# 2             1.795          1.923                             0.645
# 3             2.339          2.469                             0.758
# 4             2.449          2.596                             0.370
# ...             ...            ...                               ...
# 1964            NaN            NaN                               NaN
# 1965            NaN            NaN                               NaN
# 1966            NaN            NaN                               NaN
# 1967            NaN            NaN                               NaN
# 1968            NaN            NaN                               NaN
#
#       Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                              0.0                                  0.155
# 1                              0.0                                  0.242
# 2                              0.0                                  0.087
# 3                              0.0                                  0.289
# 4                              0.0                                  0.126
# ...                            ...                                    ...
# 1964                           NaN                                    NaN
# 1965                           NaN                                    NaN
# 1966                           NaN                                    NaN
# 1967                           NaN                                    NaN
# 1968                           NaN                                    NaN
#
#       Explained by: Freedom to make life choices  Explained by: Generosity  \
# 0                                            0.0                     0.075
# 1                                            0.0                     0.091
# 2                                            0.0                     0.093
# 3                                            0.0                     0.089
# 4                                            0.0                     0.122
# ...                                          ...                       ...
# 1964                                         NaN                       NaN
# 1965                                         NaN                       NaN
# 1966                                         NaN                       NaN
# 1967                                         NaN                       NaN
# 1968                                         NaN                       NaN
#
#       Explained by: Perceptions of corruption  Dystopia + residual
# 0                                       0.135                0.348
# 1                                       0.088                0.672
# 2                                       0.059                0.976
# 3                                       0.005                1.263
# 4                                       0.010                1.895
# ...                                       ...                  ...
# 1964                                      NaN                  NaN
# 1965                                      NaN                  NaN
# 1966                                      NaN                  NaN
# 1967                                      NaN                  NaN
# 1968                                      NaN                  NaN
#
# [1969 rows x 13 columns]

# %%
fig = px.line(happiness, x="Year", y="Life evaluation (3-year average)", color="Country name", title="World Happiness")
fig = fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="d7b2cbd3-4403-4df7-91f1-10f7a7299028" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("d7b2cbd3-4403-4df7-91f1-10f7a7299028")) {                    Plotly.newPlot(                        "d7b2cbd3-4403-4df7-91f1-10f7a7299028",                        [{"hovertemplate":"Country name=Afghanistan\u003cbr\u003eYear=%{x}\u003cbr\u003eLife evaluation (3-year average)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Afghanistan","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Afghanistan","showlegend":true,"x":{"dtype":"i2","bdata":"6AfnB+YH5QfkB+MH4gfhB+AH3wfeB9wH2wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"bef7qfHS9T\u002fwp8ZLN4n7P1g5tMh2vv0\u002fCKwcWmQ7A0DJdr6fGi8EQAEAAOACiQRAObTIdr6fCUB1kxgEVg4NQCcxCKwcWg5A4XoUrkfhCkCamZmZmZkMQClcj8L1KBBA1XjpJjEIEUA="},"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country name=Albania\u003cbr\u003eYear=%{x}\u003cbr\u003eLife evaluation (3-year average)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Albania","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Albania","showlegend":true,"x":{"dtype":"i2","bdata":"6AfnB+YH5QfkB+MH4gfhB+AH3wfeB9wH2wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"vp8aL92kFUCe76fGSzcVQM\u002f3U+OlGxVAsp3vp8bLFEArhxbZzncUQPv\u002f\u002f3\u002fihxNAx0s3iUHgEkDy0k1iEFgSQPp+arx0kxJAH4XrUbieEkC8dJMYBNYTQDMzMzMzMxZA8KfGSzeJFEA="},"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country name=Algeria\u003cbr\u003eYear=%{x}\u003cbr\u003eLife evaluation (3-year average)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Algeria","line":{"color":"#00cc96","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Algeria","showlegend":true,"x":{"dtype":"i2","bdata":"6AfnB+YH5QfkB+MH4gfhB+AH3wfeB9wH2wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"YhBYObRIFkDb+X5qvHQVQDeJQWDlUBVAsHJoke18FEA\u002fNV66SYwTQP3\u002f\u002f984BRRA8tJNYhDYFECuR+F6FC4VQLByaJHtfBdA7FG4HoVrGUDsUbgehWsWQOOlm8QgsBVARrbz\u002fdR4FUA="},"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country name=Angola\u003cbr\u003eYear=%{x}\u003cbr\u003eLife evaluation (3-year average)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Angola","line":{"color":"#ab63fa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Angola","showlegend":true,"x":{"dtype":"i2","bdata":"4QfgB98H3gfcB9sH"},"xaxis":"x","y":{"dtype":"f8","bdata":"XI\u002fC9ShcDkBcj8L1KFwOQCGwcmiR7Q5AbxKDwMohEEBCYOXQIlsWQIPAyqFFthBA"},"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country name=Argentina\u003cbr\u003eYear=%{x}\u003cbr\u003eLife evaluation (3-year average)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Argentina","line":{"color":"#FFA15A","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Argentina","showlegend":true,"x":{"dtype":"i2","bdata":"6AfnB+YH5QfkB+MH4gfhB+AH3wfeB9wH2wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"SgwCK4eWGUCNl24Sg8AYQH9qvHSTGBhAke18PzXeF0Ce76fGS7cXQAIAAMAX5hdA8tJNYhBYGEBaZDvfT40ZQEw3iUFgZRpAmpmZmZmZGkCyne+nxksaQHNoke18PxpAK4cW2c73GEA="},"yaxis":"y","type":"scattergl"},{"hovertemplate":"Country name=Armenia\u003cbr\u003eYear=%{x}\u003cbr\u003eLife evaluation (3-year average)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Armenia","line":{"color":"#19d3f3","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Armenia","showlegend":true,"x":{"dtype":"i2","bdata":"6AfnB+YH5QfkB+MH4gfhB+AH3wfeB9wH2wc="},"xaxis":"x","y":{"dtype":"f8","bdata":"YOXQItv5FUBSuB6F69EVQJHtfD81XhVAf2q8dJOYFUBvEoPAyiEVQP7\u002f\u002f\u002f8KtRJAI9v5fmo8EkBiEFg5tEgRQ ...

# %%
happiness.dtypes
# Out:
# Year                                            int64
# Rank                                            int64
# Country name                                   object
# Life evaluation (3-year average)              float64
# Lower whisker                                 float64
# Upper whisker                                 float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# Explained by: Generosity                      float64
# Explained by: Perceptions of corruption       float64
# Dystopia + residual                           float64
# dtype: object

# %% [markdown]
# ## Single country

# %%
country_name = "Madagascar"

madagascar_electricity = electricity_by_country_by_year[electricity_by_country_by_year["Country Name"] == country_name]
madagascar_electricity
# Out:
#      Country Name Country Code  Year  Access to electricity (% of population)
# 151    Madagascar          MDG  2002                                     14.0
# 417    Madagascar          MDG  2003                                     20.3
# 683    Madagascar          MDG  2004                                     15.3
# 949    Madagascar          MDG  2005                                     16.0
# 1215   Madagascar          MDG  2006                                     16.8
# 1481   Madagascar          MDG  2007                                     17.5
# 1747   Madagascar          MDG  2008                                     18.3
# 2013   Madagascar          MDG  2009                                     17.4
# 2279   Madagascar          MDG  2010                                     12.3
# 2545   Madagascar          MDG  2011                                     14.3
# 2811   Madagascar          MDG  2012                                     18.7
# 3077   Madagascar          MDG  2013                                     12.9
# 3343   Madagascar          MDG  2014                                     23.0
# 3609   Madagascar          MDG  2015                                     23.8
# 3875   Madagascar          MDG  2016                                     22.9
# 4141   Madagascar          MDG  2017                                     24.1
# 4407   Madagascar          MDG  2018                                     36.5
# 4673   Madagascar          MDG  2019                                     31.0
# 4939   Madagascar          MDG  2020                                     32.0
# 5205   Madagascar          MDG  2021                                     35.1
# 5471   Madagascar          MDG  2022                                     36.1

# %%
madagascar_happiness = happiness[happiness["Country name"] == country_name]
madagascar_happiness
# Out:
#       Year  Rank Country name  Life evaluation (3-year average)  \
# 1041  2024   130   Madagascar                            4.1570
# 1042  2023   123   Madagascar                            4.2280
# 1043  2022   127   Madagascar                            4.0190
# 1044  2021   128   Madagascar                            4.3390
# 1045  2020   136   Madagascar                            4.2080
# 1046  2019   137   Madagascar                            4.1656
# 1047  2018   143   Madagascar                            3.9330
# 1048  2017   143   Madagascar                            3.7740
# 1049  2016   144   Madagascar                            3.6440
# 1050  2015   148   Madagascar                            3.6950
# 1051  2014   147   Madagascar                            3.6810
# 1052  2012   146   Madagascar                            3.9660
# 1053  2011   129   Madagascar                            4.3090
#
#       Lower whisker  Upper whisker  Explained by: Log GDP per capita  \
# 1041       4.050000       4.265000                          0.588000
# 1042       4.097000       4.359000                          0.628000
# 1043       3.839000       4.199000                          0.632000
# 1044       4.148000       4.530000                          0.670000
# 1045       4.068000       4.349000                          0.266000
# 1046       4.052817       4.278382                          0.244553
# 1047            NaN            NaN                               NaN
# 1048            NaN            NaN                               NaN
# 1049            NaN            NaN                               NaN
# 1050            NaN            NaN                               NaN
# 1051            NaN            NaN                               NaN
# 1052            NaN            NaN                               NaN
# 1053            NaN            NaN                               NaN
#
#       Explained by: Social support  Explained by: Healthy life expectancy  \
# 1041                      0.938000                               0.341000
# 1042                      0.823000                               0.333000
# 1043                      0.779000                               0.178000
# 1044                      0.645000                               0.378000
# 1045                      0.503000                               0.341000
# 1046                      0.823694                               0.500617
# 1047                           NaN                                    NaN
# 1048                           NaN                                    NaN
# 1049                           NaN                                    NaN
# 1050                           NaN                                    NaN
# 1051                           NaN                                    NaN
# 1052                           NaN                                    NaN
# 1053                           NaN                                    NaN
#
#       Explained by: Freedom to make life choices  Explained by: Generosity  \
# 1041                                    0.292000                   0.13100
# 1042                                    0.250000                   0.17200
# 1043                                    0.187000                   0.17700
# 1044                                    0.202000                   0.14300
# 1045                                    0.207000                   0.18500
# 1046                                    0.192968                   0.19119
# 1047                                         NaN                       NaN
# 1048                                         NaN                       NaN
# 1049                                         NaN                       NaN
# 1050                                         NaN                       NaN
# 1051                                         NaN                       NaN
# 1052                                         NaN                       NaN
# 1053                                         NaN                       NaN
#
#       Explained by: Perceptions of corruption  Dystopia + residual
# 1041                                 0.118000             1.751000
# 1042                                 0.123000             1.897000
# 1043                                 0.134000             1.932000
# 1044                                 0.154000             2.148000
# 1045                                 0.087000             2.620000
# 1046                                 0.076249             2.136298
# 1047                                      NaN                  NaN
# 1048                                      NaN                  NaN
# 1049                                      NaN                  NaN
# 1050                                      NaN                  NaN
# 1051                                      NaN                  NaN
# 1052                                      NaN                  NaN
# 1053                                      NaN                  NaN

# %% [markdown]
# ## Two Y Axes
#
# Based on [Plotly example](https://plotly.com/python/multiple-axes/#Two-Y-Axes).

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Create figure with secondary y-axis
fig = make_subplots(specs=[[{"secondary_y": True}]])

# Add traces
fig.add_trace(
    go.Scatter(
        x=madagascar_electricity["Year"],
        y=madagascar_electricity["Access to electricity (% of population)"],
        name="Access to electricity",
    ),
    secondary_y=False,
)

fig.add_trace(
    go.Scatter(
        x=madagascar_happiness["Year"],
        y=madagascar_happiness["Life evaluation (3-year average)"],
        name="Life evaluation (3-year average)",
    ),
    secondary_y=True,
)

# Add figure title
fig.update_layout(title_text=f"Access to electricity vs. Happiness, {country_name}")

# Set x-axis title
fig.update_xaxes(title_text="Year")

# Set y-axes titles
fig.update_yaxes(title_text="% of population", secondary_y=False)
fig.update_yaxes(title_text="Happiness score", secondary_y=True)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.3.0.min.js" integrity="sha256-bO3dS6yCpk9aK4gUpNELtCiDeSYvGYnK7jFI58NQnHI=" crossorigin="anonymous"></script>                <div id="44e14956-6a94-45c1-b785-96d91b820f4d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("44e14956-6a94-45c1-b785-96d91b820f4d")) {                    Plotly.newPlot(                        "44e14956-6a94-45c1-b785-96d91b820f4d",                        [{"name":"Access to electricity","x":{"dtype":"i2","bdata":"0gfTB9QH1QfWB9cH2AfZB9oH2wfcB90H3gffB+AH4QfiB+MH5AflB+YH"},"y":{"dtype":"f8","bdata":"AAAAAAAALEDNzMzMzEw0QJqZmZmZmS5AAAAAAAAAMEDNzMzMzMwwQAAAAAAAgDFAzczMzMxMMkBmZmZmZmYxQJqZmZmZmShAmpmZmZmZLEAzMzMzM7MyQM3MzMzMzClAAAAAAAAAN0DNzMzMzMw3QGZmZmZm5jZAmpmZmZkZOEAAAAAAAEBCQAAAAAAAAD9AAAAAAAAAQEDNzMzMzIxBQM3MzMzMDEJA"},"type":"scatter","xaxis":"x","yaxis":"y"},{"name":"Life evaluation (3-year average)","x":{"dtype":"i2","bdata":"6AfnB+YH5QfkB+MH4gfhB+AH3wfeB9wH2wc="},"y":{"dtype":"f8","bdata":"VOOlm8SgEEC28\u002f3UeOkQQPp+arx0ExBAQmDl0CJbEUCiRbbz\u002fdQQQAQAAACTqRBAEFg5tMh2D0D+1HjpJjEOQPT91HjpJg1Aj8L1KFyPDUCmm8QgsHINQO58PzVeug9AI9v5fmo8EUA="},"type":"scatter","xaxis":"x","yaxis":"y2"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"ty ...
